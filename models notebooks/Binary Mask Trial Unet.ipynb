# %%
import cv2
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout 
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import BatchNormalization

# %%
train_inputImg = []
train_inputImg.append(pd.read_csv('../input/cephalometric-landmarks/train_senior.csv', delimiter=','))
train_inputImg.append(pd.read_csv('../input/cephalometric-landmarks/test1_senior.csv', delimiter=','))

w = 20
train_images = []
masks = []
train_masks = []

for csv_file in train_inputImg:
    for row in csv_file.values:
        img_landmarks = list(row)

        image = cv2.imread('../input/cephalometric-landmarks/cepha400/cepha400/' + img_landmarks[0], 0) / 255
        Mask_Image = np.zeros((image.shape[0],image.shape[1],1))
        
        for i in range(1,38,2):
            x = img_landmarks[i]
            y = img_landmarks[i+1]
            Mask_Image[y-w:y+w , x-w:x+w ,0] = 1
        
        masks.append(Mask_Image)

        new_image = cv2.resize(image,(256,256))
        new_image = new_image.reshape((new_image.shape[0],new_image.shape[1],1))
        train_images.append(new_image)

        resize_mask=cv2.resize(Mask_Image,(256,256))
        train_masks.append(resize_mask)

size=new_image.shape
print(size)
print (train_masks[0].shape)
plt.subplot(121)
plt.imshow(train_images[0], cmap='gray')
plt.subplot(122)
plt.imshow(train_masks[0], cmap='gray')
# Out:
# (256, 256, 1)
# (256, 256)

# %%
plt.rcParams["figure.figsize"] = (5,5)

val_test_inputImg = pd.read_csv('../input/cephalometric-landmarks/test2_senior.csv', delimiter=',')

val_images = []
val_masks_orig = []
val_masks = []

test_images = []
test_masks_orig = []
test_masks = []

count = 1

for row in val_test_inputImg.values:
    img_landmarks = list(row)

    image = cv2.imread('../input/cephalometric-landmarks/cepha400/cepha400/' + img_landmarks[0], 0) / 255
    Mask_Image = np.zeros((image.shape[0],image.shape[1],1))
    
    for i in range(1,38,2):
        x = img_landmarks[i]
        y = img_landmarks[i+1]
        Mask_Image[y-w:y+w , x-w:x+w ,0] = 1
         

    new_image = cv2.resize(image,(256,256))
    new_image = new_image.reshape((new_image.shape[0],new_image.shape[1],1))
    resize_mask=cv2.resize(Mask_Image,(256,256))
    
    if count <= 50:
        val_images.append(new_image)
        val_masks_orig.append(Mask_Image)
        val_masks.append(resize_mask)
    else:
        test_images.append(new_image)
        test_masks_orig.append(Mask_Image)
        test_masks.append(resize_mask)
    
    count += 1
    
size=new_image.shape
print(size)
print (val_masks[0].shape)
print(val_images[0].shape)
plt.subplot(221)
plt.imshow(val_images[0], cmap='gray')
plt.title("Validation")
plt.subplot(222)
plt.imshow(val_masks[0], cmap='gray')

plt.subplot(223)
plt.imshow(test_images[0], cmap='gray')
plt.title("Test")
plt.subplot(224)
plt.imshow(test_masks[0], cmap='gray')
# Out:
# (256, 256, 1)
# (256, 256)
# (256, 256, 1)

# %%
train_images_stacked = np.stack(train_images, axis=0)
train_masks_stacked = np.stack(train_masks, axis=0)

val_images_stacked = np.stack(val_images, axis=0)
val_masks_stacked = np.stack(val_masks, axis=0)
val_data = (val_images_stacked, val_masks_stacked)

# %%
print(train_images_stacked.shape)
print(train_masks_stacked.shape)
# Out:
# (300, 256, 256, 1)
# (300, 256, 256)

# %%
def conv_block(inputs=None, n_filters=32, dropout_prob=0, max_pooling=True):
    """
    Convolutional downsampling block
    
    Arguments:
        inputs -- Input tensor
        n_filters -- Number of filters for the convolutional layers
        dropout_prob -- Dropout probability
        max_pooling -- Use MaxPooling2D to reduce the spatial dimensions of the output volume
    Returns: 
        next_layer, skip_connection --  Next layer and skip connection outputs
    """

    conv = Conv2D(n_filters, # Number of filters
                  3,   # Kernel size   
                  activation='relu',
                  padding='same',
                  kernel_initializer='he_normal')(inputs)
    
    conv = BatchNormalization()(conv)
    
    conv = Conv2D(n_filters, # Number of filters
                  3,   # Kernel size
                  activation='relu',
                  padding='same',
                  kernel_initializer='he_normal')(conv)
    conv = BatchNormalization()(conv)
    
    # if dropout_prob > 0 add a dropout layer, with the variable dropout_prob as parameter
    if dropout_prob > 0:
        conv = Dropout(dropout_prob)(conv)
         
        
    # if max_pooling is True add a MaxPooling2D with 2x2 pool_size
    if max_pooling:
        next_layer = MaxPooling2D((2,2))(conv)
        
    else:
        next_layer = conv
        
    skip_connection = conv
    
    return next_layer, skip_connection

# %%
def upsampling_block(expansive_input, contractive_input, n_filters=32, output=False):
    """
    Convolutional upsampling block
    
    Arguments:
        expansive_input -- Input tensor from previous layer
        contractive_input -- Input tensor from previous skip layer
        n_filters -- Number of filters for the convolutional layers
    Returns: 
        conv -- Tensor output
    """
    
    up = Conv2DTranspose(
                 n_filters,    # number of filters
                 3,    # Kernel size
                 strides=2,
                 padding='same')(expansive_input)
    
    # Merge the previous output and the contractive_input
    merge = concatenate([up, contractive_input], axis=3)
    conv = Conv2D(n_filters, # Number of filters
                  3,   # Kernel size   
                  activation='relu',
                  padding='same',
                  kernel_initializer='he_normal')(merge)
    conv = BatchNormalization()(conv)
        
    conv = Conv2D(n_filters, # Number of filters
                  3,   # Kernel size
                  activation='relu',
                  padding='same',
                  kernel_initializer='he_normal')(conv)
    conv = BatchNormalization()(conv)
    
    if not output:
        conv = Conv2D(n_filters, # Number of filters
                  3,   # Kernel size
                  activation='relu',
                  padding='same',
                  kernel_initializer='he_normal')(conv)
        conv = BatchNormalization()(conv)
    
    return conv

# %%
def unet_model(input_size, n_filters=64, n_classes=2):
    """
    Unet model
    
    Arguments:
        input_size -- Input shape 
        n_filters -- Number of filters for the convolutional layers
        n_classes -- Number of output classes
    Returns: 
        model -- tf.keras.Model
    """
    inputs = Input(input_size)
    
    # Contracting Path (encoding)
    # Add a conv_block with the inputs of the unet_ model and n_filters
    cblock1 = conv_block(inputs, n_filters)
    
    # Chain the first element of the output of each block to be the input of the next conv_block. 
    # Double the number of filters at each new step
    cblock2 = conv_block(cblock1[0], n_filters*2)
    cblock3 = conv_block(cblock2[0], n_filters*4)
    cblock4 = conv_block(cblock3[0], n_filters*8, dropout_prob=0) # Include a dropout_prob of 0.3 for this layer
    # Include a dropout_prob of 0.3 for this layer, and avoid the max_pooling layer
    cblock5 = conv_block(cblock4[0], n_filters*16, dropout_prob=0, max_pooling=False) 
    
    # Expanding Path (decoding)
    # Add the first upsampling_block.
    # Use the cblock5[0] as expansive_input and cblock4[1] as contractive_input and n_filters * 8
    ublock6 = upsampling_block(cblock5[0], cblock4[1],  n_filters*8, False)
    
    # Chain the output of the previous block as expansive_input and the corresponding contractive block output.
    # Note that you must use the second element of the contractive block i.e before the maxpooling layer. 
    # At each step, use half the number of filters of the previous block 
    ublock7 = upsampling_block(ublock6, cblock3[1],  n_filters * 4, False)
    ublock8 = upsampling_block(ublock7, cblock2[1],  n_filters * 2, False)
    ublock9 = upsampling_block(ublock8, cblock1[1],  n_filters, True)

    #conv9 = Conv2D(n_filters,
    #             3,
    #             activation='relu',
    #             padding='same',
    #            kernel_initializer='he_normal')(ublock9)

    # Add a Conv2D layer with n_classes filter, kernel size of 1 and a 'same' padding
    conv10 = Conv2D(n_classes, kernel_size=1, activation='sigmoid', padding='same')(ublock9)
    
    model = tf.keras.Model(inputs=inputs, outputs=conv10)

    return model

# %%
epsilon = 1e-7
def dice_coeff(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + epsilon) / ( K.sum(y_true_f) + K.sum(y_pred_f) + epsilon)
    return dice

# %%
def dice_loss(y_true, y_pred):
    dice = dice_coeff(y_true, y_pred)
    return 1 - dice

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10)
checkpoint_filepath = '/kaggle/working/checkpoint_20channels'
checkpoint_20channels = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_dice_coeff',
    save_best_only=True)

# %%
print(size)
unet = unet_model(size, n_classes=1)
# Out:
# (256, 256, 1)

# %%
unet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=dice_loss,
              metrics=dice_coeff)

# %%
model_history = unet.fit(train_images_stacked, train_masks_stacked, batch_size = 32, epochs=200, validation_data=val_data, callbacks=[reduce_lr])
# Out:
# 2022-12-18 12:46:00.246865: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2022-12-18 12:46:03.533337: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 2022-12-18 12:46:17.343717: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.39GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-12-18 12:46:17.499650: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.39GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 10/10 [==============================] - 40s 2s/step - loss: 0.9713 - dice_coeff: 0.0300 - val_loss: 0.9872 - val_dice_coeff: 0.0128
# Epoch 2/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.9415 - dice_coeff: 0.0593 - val_loss: 0.9872 - val_dice_coeff: 0.0128
# Epoch 3/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.9228 - dice_coeff: 0.0776 - val_loss: 0.9869 - val_dice_coeff: 0.0131
# Epoch 4/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.9065 - dice_coeff: 0.0941 - val_loss: 0.9867 - val_dice_coeff: 0.0133
# Epoch 5/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.8923 - dice_coeff: 0.1075 - val_loss: 0.9863 - val_dice_coeff: 0.0137
# Epoch 6/200
# 10/10 [==============================] - 9s 922ms/step - loss: 0.8821 - dice_coeff: 0.1189 - val_loss: 0.9857 - val_dice_coeff: 0.0143
# Epoch 7/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.8557 - dice_coeff: 0.1452 - val_loss: 0.9673 - val_dice_coeff: 0.0326
# Epoch 8/200
# 10/10 [==============================] - 9s 926ms/step - loss: 0.8300 - dice_coeff: 0.1711 - val_loss: 0.9761 - val_dice_coeff: 0.0240
# Epoch 9/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.8619 - dice_coeff: 0.1401 - val_loss: 0.9871 - val_dice_coeff: 0.0129
# Epoch 10/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.8254 - dice_coeff: 0.1759 - val_loss: 0.9851 - val_dice_coeff: 0.0149
# Epoch 11/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.7884 - dice_coeff: 0.2125 - val_loss: 0.9838 - val_dice_coeff: 0.0163
# Epoch 12/200
# 10/10 [==============================] - 9s 942ms/step - loss: 0.7529 - dice_coeff: 0.2480 - val_loss: 0.9714 - val_dice_coeff: 0.0286
# Epoch 13/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.7442 - dice_coeff: 0.2554 - val_loss: 0.9831 - val_dice_coeff: 0.0169
# Epoch 14/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.7750 - dice_coeff: 0.2276 - val_loss: 0.9827 - val_dice_coeff: 0.0173
# Epoch 15/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.7036 - dice_coeff: 0.2978 - val_loss: 0.9843 - val_dice_coeff: 0.0157
# Epoch 16/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.6321 - dice_coeff: 0.3692 - val_loss: 0.9853 - val_dice_coeff: 0.0148
# Epoch 17/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.6062 - dice_coeff: 0.3958 - val_loss: 0.9842 - val_dice_coeff: 0.0159
# Epoch 18/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.5429 - dice_coeff: 0.4591 - val_loss: 0.9788 - val_dice_coeff: 0.0213
# Epoch 19/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.5154 - dice_coeff: 0.4843 - val_loss: 0.9788 - val_dice_coeff: 0.0211
# Epoch 20/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.4946 - dice_coeff: 0.5051 - val_loss: 0.9872 - val_dice_coeff: 0.0130
# Epoch 21/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.4701 - dice_coeff: 0.5300 - val_loss: 0.7319 - val_dice_coeff: 0.2695
# Epoch 22/200
# 10/10 [==============================] - 9s 942ms/step - loss: 0.4554 - dice_coeff: 0.5451 - val_loss: 0.9838 - val_dice_coeff: 0.0164
# Epoch 23/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.4449 - dice_coeff: 0.5558 - val_loss: 0.9896 - val_dice_coeff: 0.0105
# Epoch 24/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.4386 - dice_coeff: 0.5610 - val_loss: 0.9835 - val_dice_coeff: 0.0168
# Epoch 25/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.4332 - dice_coeff: 0.5664 - val_loss: 0.9802 - val_dice_coeff: 0.0201
# Epoch 26/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.4163 - dice_coeff: 0.5838 - val_loss: 0.9858 - val_dice_coeff: 0.0142
# Epoch 27/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.4076 - dice_coeff: 0.5916 - val_loss: 0.9414 - val_dice_coeff: 0.0593
# Epoch 28/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.4049 - dice_coeff: 0.5933 - val_loss: 0.5900 - val_dice_coeff: 0.4140
# Epoch 29/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.3963 - dice_coeff: 0.6041 - val_loss: 0.5572 - val_dice_coeff: 0.4467
# Epoch 30/200
# 10/10 [==============================] - 9s 942ms/step - loss: 0.3901 - dice_coeff: 0.6107 - val_loss: 0.5925 - val_dice_coeff: 0.4104
# Epoch 31/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.3904 - dice_coeff: 0.6103 - val_loss: 0.5917 - val_dice_coeff: 0.4126
# Epoch 32/200
# 10/10 [==============================] - 9s 927ms/step - loss: 0.3967 - dice_coeff: 0.6055 - val_loss: 0.5542 - val_dice_coeff: 0.4493
# Epoch 33/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.3815 - dice_coeff: 0.6171 - val_loss: 0.5868 - val_dice_coeff: 0.4182
# Epoch 34/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.3762 - dice_coeff: 0.6231 - val_loss: 0.5748 - val_dice_coeff: 0.4289
# Epoch 35/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.3713 - dice_coeff: 0.6272 - val_loss: 0.5517 - val_dice_coeff: 0.4523
# Epoch 36/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.3713 - dice_coeff: 0.6299 - val_loss: 0.5821 - val_dice_coeff: 0.4213
# Epoch 37/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.3629 - dice_coeff: 0.6372 - val_loss: 0.5335 - val_dice_coeff: 0.4699
# Epoch 38/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.3621 - dice_coeff: 0.6384 - val_loss: 0.5475 - val_dice_coeff: 0.4566
# Epoch 39/200
# 10/10 [==============================] - 9s 942ms/step - loss: 0.3570 - dice_coeff: 0.6401 - val_loss: 0.5609 - val_dice_coeff: 0.4415
# Epoch 40/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.3515 - dice_coeff: 0.6482 - val_loss: 0.5277 - val_dice_coeff: 0.4749
# Epoch 41/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.3535 - dice_coeff: 0.6478 - val_loss: 0.5173 - val_dice_coeff: 0.4860
# Epoch 42/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.3421 - dice_coeff: 0.6570 - val_loss: 0.5134 - val_dice_coeff: 0.4911
# Epoch 43/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.3372 - dice_coeff: 0.6619 - val_loss: 0.5261 - val_dice_coeff: 0.4782
# Epoch 44/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.3433 - dice_coeff: 0.6561 - val_loss: 0.5540 - val_dice_coeff: 0.4499
# Epoch 45/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.3376 - dice_coeff: 0.6623 - val_loss: 0.5334 - val_dice_coeff: 0.4704
# Epoch 46/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.3462 - dice_coeff: 0.6560 - val_loss: 0.5198 - val_dice_coeff: 0.4832
# Epoch 47/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.3496 - dice_coeff: 0.6486 - val_loss: 0.5302 - val_dice_coeff: 0.4743
# Epoch 48/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.3467 - dice_coeff: 0.6542 - val_loss: 0.5299 - val_dice_coeff: 0.4743
# Epoch 49/200
# 10/10 [==============================] - 9s 926ms/step - loss: 0.3382 - dice_coeff: 0.6606 - val_loss: 0.5009 - val_dice_coeff: 0.5016
# Epoch 50/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.3326 - dice_coeff: 0.6684 - val_loss: 0.5148 - val_dice_coeff: 0.4869
# Epoch 51/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.3374 - dice_coeff: 0.6634 - val_loss: 0.5105 - val_dice_coeff: 0.4909
# Epoch 52/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.3339 - dice_coeff: 0.6657 - val_loss: 0.5257 - val_dice_coeff: 0.4766
# Epoch 53/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.3216 - dice_coeff: 0.6772 - val_loss: 0.4871 - val_dice_coeff: 0.5157
# Epoch 54/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.3189 - dice_coeff: 0.6811 - val_loss: 0.5061 - val_dice_coeff: 0.4965
# Epoch 55/200
# 10/10 [==============================] - 9s 942ms/step - loss: 0.3208 - dice_coeff: 0.6776 - val_loss: 0.4951 - val_dice_coeff: 0.5076
# Epoch 56/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.3164 - dice_coeff: 0.6832 - val_loss: 0.5034 - val_dice_coeff: 0.4990
# Epoch 57/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.3145 - dice_coeff: 0.6872 - val_loss: 0.4827 - val_dice_coeff: 0.5204
# Epoch 58/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.3279 - dice_coeff: 0.6720 - val_loss: 0.5064 - val_dice_coeff: 0.4956
# Epoch 59/200
# 10/10 [==============================] - 9s 927ms/step - loss: 0.3209 - dice_coeff: 0.6792 - val_loss: 0.4857 - val_dice_coeff: 0.5168
# Epoch 60/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.3235 - dice_coeff: 0.6762 - val_loss: 0.5246 - val_dice_coeff: 0.4778
# Epoch 61/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.3136 - dice_coeff: 0.6866 - val_loss: 0.4812 - val_dice_coeff: 0.5207
# Epoch 62/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.3110 - dice_coeff: 0.6900 - val_loss: 0.4898 - val_dice_coeff: 0.5118
# Epoch 63/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.3091 - dice_coeff: 0.6916 - val_loss: 0.4989 - val_dice_coeff: 0.5025
# Epoch 64/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.3071 - dice_coeff: 0.6929 - val_loss: 0.5043 - val_dice_coeff: 0.4972
# Epoch 65/200
# 10/10 [==============================] - 9s 926ms/step - loss: 0.2988 - dice_coeff: 0.7005 - val_loss: 0.4806 - val_dice_coeff: 0.5214
# Epoch 66/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.2975 - dice_coeff: 0.7024 - val_loss: 0.4722 - val_dice_coeff: 0.5305
# Epoch 67/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.2969 - dice_coeff: 0.7018 - val_loss: 0.4845 - val_dice_coeff: 0.5177
# Epoch 68/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.2927 - dice_coeff: 0.7069 - val_loss: 0.4941 - val_dice_coeff: 0.5077
# Epoch 69/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.2889 - dice_coeff: 0.7109 - val_loss: 0.4819 - val_dice_coeff: 0.5204
# Epoch 70/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.2886 - dice_coeff: 0.7098 - val_loss: 0.4658 - val_dice_coeff: 0.5357
# Epoch 71/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.2960 - dice_coeff: 0.7040 - val_loss: 0.4916 - val_dice_coeff: 0.5104
# Epoch 72/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.2922 - dice_coeff: 0.7067 - val_loss: 0.4817 - val_dice_coeff: 0.5209
# Epoch 73/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.2887 - dice_coeff: 0.7114 - val_loss: 0.4969 - val_dice_coeff: 0.5051
# Epoch 74/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.2919 - dice_coeff: 0.7084 - val_loss: 0.4759 - val_dice_coeff: 0.5268
# Epoch 75/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.2838 - dice_coeff: 0.7157 - val_loss: 0.4785 - val_dice_coeff: 0.5233
# Epoch 76/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.2951 - dice_coeff: 0.7038 - val_loss: 0.5020 - val_dice_coeff: 0.5003
# Epoch 77/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.2912 - dice_coeff: 0.7080 - val_loss: 0.4905 - val_dice_coeff: 0.5099
# Epoch 78/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.2834 - dice_coeff: 0.7164 - val_loss: 0.4884 - val_dice_coeff: 0.5123
# Epoch 79/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.2783 - dice_coeff: 0.7220 - val_loss: 0.4853 - val_dice_coeff: 0.5160
# Epoch 80/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.2749 - dice_coeff: 0.7259 - val_loss: 0.4859 - val_dice_coeff: 0.5166
# Epoch 81/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.2657 - dice_coeff: 0.7345 - val_loss: 0.4779 - val_dice_coeff: 0.5230
# Epoch 82/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.2592 - dice_coeff: 0.7401 - val_loss: 0.4831 - val_dice_coeff: 0.5172
# Epoch 83/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.2541 - dice_coeff: 0.7461 - val_loss: 0.4837 - val_dice_coeff: 0.5170
# Epoch 84/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.2491 - dice_coeff: 0.7508 - val_loss: 0.4733 - val_dice_coeff: 0.5272
# Epoch 85/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.2467 - dice_coeff: 0.7528 - val_loss: 0.4875 - val_dice_coeff: 0.5140
# Epoch 86/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.2448 - dice_coeff: 0.7548 - val_loss: 0.4835 - val_dice_coeff: 0.5172
# Epoch 87/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.2410 - dice_coeff: 0.7586 - val_loss: 0.4803 - val_dice_coeff: 0.5223
# Epoch 88/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.2365 - dice_coeff: 0.7642 - val_loss: 0.4676 - val_dice_coeff: 0.5343
# Epoch 89/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.2338 - dice_coeff: 0.7669 - val_loss: 0.4828 - val_dice_coeff: 0.5189
# Epoch 90/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.2308 - dice_coeff: 0.7684 - val_loss: 0.4800 - val_dice_coeff: 0.5214
# Epoch 91/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.2263 - dice_coeff: 0.7746 - val_loss: 0.4809 - val_dice_coeff: 0.5211
# Epoch 92/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.2237 - dice_coeff: 0.7759 - val_loss: 0.4783 - val_dice_coeff: 0.5236
# Epoch 93/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.2198 - dice_coeff: 0.7788 - val_loss: 0.4736 - val_dice_coeff: 0.5276
# Epoch 94/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.2147 - dice_coeff: 0.7851 - val_loss: 0.4732 - val_dice_coeff: 0.5284
# Epoch 95/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.2112 - dice_coeff: 0.7884 - val_loss: 0.4752 - val_dice_coeff: 0.5267
# Epoch 96/200
# 10/10 [==============================] - 9s 944ms/step - loss: 0.2084 - dice_coeff: 0.7925 - val_loss: 0.4665 - val_dice_coeff: 0.5354
# Epoch 97/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.2058 - dice_coeff: 0.7941 - val_loss: 0.4788 - val_dice_coeff: 0.5232
# Epoch 98/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.2038 - dice_coeff: 0.7974 - val_loss: 0.4817 - val_dice_coeff: 0.5200
# Epoch 99/200
# 10/10 [==============================] - 9s 926ms/step - loss: 0.2031 - dice_coeff: 0.7971 - val_loss: 0.4762 - val_dice_coeff: 0.5261
# Epoch 100/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1998 - dice_coeff: 0.7986 - val_loss: 0.4791 - val_dice_coeff: 0.5233
# Epoch 101/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1967 - dice_coeff: 0.8043 - val_loss: 0.4749 - val_dice_coeff: 0.5274
# Epoch 102/200
# 10/10 [==============================] - 9s 945ms/step - loss: 0.1931 - dice_coeff: 0.8066 - val_loss: 0.4762 - val_dice_coeff: 0.5262
# Epoch 103/200
# 10/10 [==============================] - 9s 939ms/step - loss: 0.1911 - dice_coeff: 0.8083 - val_loss: 0.4733 - val_dice_coeff: 0.5293
# Epoch 104/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1884 - dice_coeff: 0.8117 - val_loss: 0.4758 - val_dice_coeff: 0.5270
# Epoch 105/200
# 10/10 [==============================] - 9s 942ms/step - loss: 0.1880 - dice_coeff: 0.8129 - val_loss: 0.4739 - val_dice_coeff: 0.5288
# Epoch 106/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1865 - dice_coeff: 0.8131 - val_loss: 0.4748 - val_dice_coeff: 0.5276
# Epoch 107/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1843 - dice_coeff: 0.8156 - val_loss: 0.4771 - val_dice_coeff: 0.5254
# Epoch 108/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1837 - dice_coeff: 0.8178 - val_loss: 0.4787 - val_dice_coeff: 0.5231
# Epoch 109/200
# 10/10 [==============================] - 9s 928ms/step - loss: 0.1824 - dice_coeff: 0.8171 - val_loss: 0.4777 - val_dice_coeff: 0.5247
# Epoch 110/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1811 - dice_coeff: 0.8181 - val_loss: 0.4788 - val_dice_coeff: 0.5238
# Epoch 111/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1799 - dice_coeff: 0.8212 - val_loss: 0.4766 - val_dice_coeff: 0.5260
# Epoch 112/200
# 10/10 [==============================] - 9s 926ms/step - loss: 0.1780 - dice_coeff: 0.8211 - val_loss: 0.4774 - val_dice_coeff: 0.5247
# Epoch 113/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1772 - dice_coeff: 0.8236 - val_loss: 0.4791 - val_dice_coeff: 0.5230
# Epoch 114/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1762 - dice_coeff: 0.8224 - val_loss: 0.4781 - val_dice_coeff: 0.5242
# Epoch 115/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.1751 - dice_coeff: 0.8242 - val_loss: 0.4770 - val_dice_coeff: 0.5252
# Epoch 116/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1746 - dice_coeff: 0.8240 - val_loss: 0.4785 - val_dice_coeff: 0.5231
# Epoch 117/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1751 - dice_coeff: 0.8259 - val_loss: 0.4782 - val_dice_coeff: 0.5235
# Epoch 118/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1738 - dice_coeff: 0.8263 - val_loss: 0.4797 - val_dice_coeff: 0.5222
# Epoch 119/200
# 10/10 [==============================] - 9s 942ms/step - loss: 0.1731 - dice_coeff: 0.8252 - val_loss: 0.4766 - val_dice_coeff: 0.5255
# Epoch 120/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1728 - dice_coeff: 0.8268 - val_loss: 0.4777 - val_dice_coeff: 0.5243
# Epoch 121/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1714 - dice_coeff: 0.8282 - val_loss: 0.4762 - val_dice_coeff: 0.5258
# Epoch 122/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1709 - dice_coeff: 0.8296 - val_loss: 0.4777 - val_dice_coeff: 0.5242
# Epoch 123/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1709 - dice_coeff: 0.8270 - val_loss: 0.4776 - val_dice_coeff: 0.5244
# Epoch 124/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1698 - dice_coeff: 0.8287 - val_loss: 0.4770 - val_dice_coeff: 0.5249
# Epoch 125/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1699 - dice_coeff: 0.8317 - val_loss: 0.4775 - val_dice_coeff: 0.5243
# Epoch 126/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1690 - dice_coeff: 0.8318 - val_loss: 0.4772 - val_dice_coeff: 0.5247
# Epoch 127/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1694 - dice_coeff: 0.8310 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 128/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1686 - dice_coeff: 0.8321 - val_loss: 0.4772 - val_dice_coeff: 0.5248
# Epoch 129/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1681 - dice_coeff: 0.8318 - val_loss: 0.4774 - val_dice_coeff: 0.5247
# Epoch 130/200
# 10/10 [==============================] - 9s 942ms/step - loss: 0.1679 - dice_coeff: 0.8330 - val_loss: 0.4769 - val_dice_coeff: 0.5250
# Epoch 131/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1678 - dice_coeff: 0.8307 - val_loss: 0.4769 - val_dice_coeff: 0.5250
# Epoch 132/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1676 - dice_coeff: 0.8314 - val_loss: 0.4768 - val_dice_coeff: 0.5250
# Epoch 133/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1674 - dice_coeff: 0.8323 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 134/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1673 - dice_coeff: 0.8322 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 135/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1670 - dice_coeff: 0.8325 - val_loss: 0.4769 - val_dice_coeff: 0.5250
# Epoch 136/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1671 - dice_coeff: 0.8318 - val_loss: 0.4769 - val_dice_coeff: 0.5250
# Epoch 137/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1669 - dice_coeff: 0.8334 - val_loss: 0.4769 - val_dice_coeff: 0.5251
# Epoch 138/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1668 - dice_coeff: 0.8324 - val_loss: 0.4769 - val_dice_coeff: 0.5250
# Epoch 139/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1666 - dice_coeff: 0.8326 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 140/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1663 - dice_coeff: 0.8334 - val_loss: 0.4763 - val_dice_coeff: 0.5257
# Epoch 141/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1663 - dice_coeff: 0.8341 - val_loss: 0.4765 - val_dice_coeff: 0.5255
# Epoch 142/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1664 - dice_coeff: 0.8337 - val_loss: 0.4763 - val_dice_coeff: 0.5257
# Epoch 143/200
# 10/10 [==============================] - 9s 929ms/step - loss: 0.1661 - dice_coeff: 0.8334 - val_loss: 0.4765 - val_dice_coeff: 0.5255
# Epoch 144/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1661 - dice_coeff: 0.8345 - val_loss: 0.4767 - val_dice_coeff: 0.5253
# Epoch 145/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1659 - dice_coeff: 0.8344 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 146/200
# 10/10 [==============================] - 9s 926ms/step - loss: 0.1660 - dice_coeff: 0.8328 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 147/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1660 - dice_coeff: 0.8333 - val_loss: 0.4769 - val_dice_coeff: 0.5250
# Epoch 148/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1660 - dice_coeff: 0.8324 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 149/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1658 - dice_coeff: 0.8331 - val_loss: 0.4770 - val_dice_coeff: 0.5250
# Epoch 150/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.1657 - dice_coeff: 0.8334 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 151/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1661 - dice_coeff: 0.8331 - val_loss: 0.4767 - val_dice_coeff: 0.5253
# Epoch 152/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1657 - dice_coeff: 0.8342 - val_loss: 0.4767 - val_dice_coeff: 0.5253
# Epoch 153/200
# 10/10 [==============================] - 9s 926ms/step - loss: 0.1656 - dice_coeff: 0.8346 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 154/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1657 - dice_coeff: 0.8356 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 155/200
# 10/10 [==============================] - 9s 939ms/step - loss: 0.1655 - dice_coeff: 0.8342 - val_loss: 0.4767 - val_dice_coeff: 0.5253
# Epoch 156/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1654 - dice_coeff: 0.8339 - val_loss: 0.4768 - val_dice_coeff: 0.5252
# Epoch 157/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1654 - dice_coeff: 0.8343 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 158/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1655 - dice_coeff: 0.8342 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 159/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1655 - dice_coeff: 0.8357 - val_loss: 0.4766 - val_dice_coeff: 0.5253
# Epoch 160/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1652 - dice_coeff: 0.8344 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 161/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1657 - dice_coeff: 0.8341 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 162/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1656 - dice_coeff: 0.8318 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 163/200
# 10/10 [==============================] - 9s 926ms/step - loss: 0.1654 - dice_coeff: 0.8336 - val_loss: 0.4767 - val_dice_coeff: 0.5253
# Epoch 164/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1654 - dice_coeff: 0.8342 - val_loss: 0.4767 - val_dice_coeff: 0.5253
# Epoch 165/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1654 - dice_coeff: 0.8356 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 166/200
# 10/10 [==============================] - 9s 927ms/step - loss: 0.1651 - dice_coeff: 0.8360 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 167/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1653 - dice_coeff: 0.8334 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 168/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1654 - dice_coeff: 0.8354 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 169/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1654 - dice_coeff: 0.8352 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 170/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1654 - dice_coeff: 0.8352 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 171/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1652 - dice_coeff: 0.8347 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 172/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.1654 - dice_coeff: 0.8336 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 173/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1650 - dice_coeff: 0.8353 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 174/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1651 - dice_coeff: 0.8354 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 175/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1654 - dice_coeff: 0.8350 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 176/200
# 10/10 [==============================] - 9s 946ms/step - loss: 0.1654 - dice_coeff: 0.8358 - val_loss: 0.4767 - val_dice_coeff: 0.5252
# Epoch 177/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.1653 - dice_coeff: 0.8352 - val_loss: 0.4768 - val_dice_coeff: 0.5252
# Epoch 178/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.1650 - dice_coeff: 0.8356 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 179/200
# 10/10 [==============================] - 9s 926ms/step - loss: 0.1653 - dice_coeff: 0.8339 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 180/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1648 - dice_coeff: 0.8353 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 181/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1653 - dice_coeff: 0.8339 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 182/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1653 - dice_coeff: 0.8322 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 183/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1650 - dice_coeff: 0.8340 - val_loss: 0.4768 - val_dice_coeff: 0.5252
# Epoch 184/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1653 - dice_coeff: 0.8350 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 185/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1649 - dice_coeff: 0.8349 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 186/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1650 - dice_coeff: 0.8350 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 187/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1649 - dice_coeff: 0.8346 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 188/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1651 - dice_coeff: 0.8325 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 189/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.1654 - dice_coeff: 0.8354 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 190/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1650 - dice_coeff: 0.8353 - val_loss: 0.4768 - val_dice_coeff: 0.5252
# Epoch 191/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1652 - dice_coeff: 0.8350 - val_loss: 0.4768 - val_dice_coeff: 0.5252
# Epoch 192/200
# 10/10 [==============================] - 9s 939ms/step - loss: 0.1652 - dice_coeff: 0.8355 - val_loss: 0.4768 - val_dice_coeff: 0.5252
# Epoch 193/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1653 - dice_coeff: 0.8357 - val_loss: 0.4768 - val_dice_coeff: 0.5252
# Epoch 194/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1652 - dice_coeff: 0.8353 - val_loss: 0.4768 - val_dice_coeff: 0.5252
# Epoch 195/200
# 10/10 [==============================] - 9s 941ms/step - loss: 0.1655 - dice_coeff: 0.8338 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 196/200
# 10/10 [==============================] - 9s 924ms/step - loss: 0.1653 - dice_coeff: 0.8365 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 197/200
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1653 - dice_coeff: 0.8347 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 198/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1650 - dice_coeff: 0.8366 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 199/200
# 10/10 [==============================] - 9s 923ms/step - loss: 0.1655 - dice_coeff: 0.8340 - val_loss: 0.4768 - val_dice_coeff: 0.5251
# Epoch 200/200
# 10/10 [==============================] - 9s 925ms/step - loss: 0.1651 - dice_coeff: 0.8354 - val_loss: 0.4768 - val_dice_coeff: 0.5251

# %%
unet.save('Midterm_Model.h5')

# %%
unet.save('Midterm_Model')
# Out:
# 2022-12-18 13:18:29.882775: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(15,5))

ax1.plot(model_history.history['loss'])
ax1.plot(model_history.history['val_loss'])
ax1.legend(['Training loss', 'val_loss'])

ax2.plot(model_history.history['val_dice_coeff'])
ax2.plot(model_history.history['dice_coeff'])
ax2.legend(['val_dice_coeff', 'dice_coeff'])

# %%
test_images_stacked = np.stack(test_images, axis=0)
test_masks_stacked = np.stack(test_masks, axis=0)

# %%
pred_masks = unet.predict(test_images_stacked)

# %%
plt.rcParams["figure.figsize"] = (15,15)
for i in range(1,6):
    plt.subplot(1,5,i)
    plt.imshow(pred_masks[i-1], cmap='gray')

# %%
plt.rcParams["figure.figsize"] = (5,5)
idx = 2
test_im_gray = test_images_stacked[idx]   # dimension (256, 256, 1)
test_im_gray_convert = test_im_gray[:,:,0].astype(np.float32) # cv2 accepts dimension(256,256) and float32
# convert to RGB
test_im_rgb = cv2.cvtColor(test_im_gray_convert, cv2.COLOR_GRAY2RGB) 
print(test_im_rgb.shape)
plt.imshow(test_im_rgb)
# Out:
# (256, 256, 3)

# %%
print(pred_masks.shape)
print(pred_masks[0].shape)
print(pred_masks[0][0].shape)
print(pred_masks[0][:,:,0].shape)
# Out:
# (50, 256, 256, 1)
# (256, 256, 1)
# (256, 1)
# (256, 256)

# %%
plt.rcParams["figure.figsize"] = (10,10)

im_copy = test_im_rgb.copy()

test_im_rgb[:,:,1] = test_im_rgb[:,:,1] + test_masks[idx]
maxValue1 = np.amax(test_im_rgb)
minValue1 = np.amin(test_im_rgb)
print("max: ", maxValue1)
print("min: ", minValue1)
print("Uniqueeee1: ",np.unique(test_im_rgb))
plt.subplot(231)
plt.imshow(test_im_rgb/maxValue1)
plt.title("True")


plt.subplot(232)
plt.imshow(test_im_rgb)
plt.title("True w/o scaling ")

plt.subplot(233)
plt.imshow(test_masks[idx], cmap='gray')
plt.title("True Mask")

im_copy[:,:,0] = im_copy[:,:,0] + pred_masks[idx][:,:,0]
maxValue2 = np.amax(im_copy)
minValue2 = np.amin(im_copy)
print("max: ", maxValue2)
print("min: ", minValue2)
print("Uniqueeee2: ",np.unique(im_copy))
plt.subplot(234)
plt.imshow(im_copy/maxValue2)
plt.title("Predicted")

plt.subplot(235)
plt.imshow(im_copy)
plt.title("Predicted w/o scaling ")

plt.subplot(236)
plt.imshow(pred_masks[idx], cmap='gray')
plt.title("Predicted Mask")
# Out:
# max:  1.7529411
# min:  0.031976197
# Uniqueeee1:  [0.0319762  0.03485658 0.03991316 ... 1.7487745  1.7490196  1.7529411 ]
# max:  1.7594745
# min:  0.031976197
# Uniqueeee2:  [0.0319762  0.03202205 0.03485658 ... 1.7403722  1.7556362  1.7594745 ]
# Text(0.5, 1.0, 'Predicted Mask')

# %%
plt.subplot(221)
plt.imshow(test_im_rgb)
plt.title("True")

plt.subplot(222)
plt.imshow(im_copy)
plt.title("Predicted")

plt.subplot(223)
plt.imshow(test_masks[idx], cmap='gray')
plt.title("True Mask")

plt.subplot(224)
plt.imshow(pred_masks[idx], cmap='gray')
plt.title("Predicted Mask")
# Out:
# Text(0.5, 1.0, 'Predicted Mask')

# %%
resized = cv2.resize(test_im_rgb, (1935,2400))
plt.imshow(resized)

# %%
origi_img = cv2.imread('../input/cephalometric-landmarks/cepha400/cepha400/386.jpg') / 255
print(origi_img.shape)
print(test_masks_orig[0].shape)
# Out:
# (2400, 1935, 3)
# (2400, 1935, 1)

# %%
origi_img[:,:,0] = origi_img[:,:,0] + test_masks_orig[idx][:,:,0]
plt.imshow(origi_img)

# %%
im_copy_resized = cv2.resize(im_copy, (1935,2400))

# %%
plt.subplot(121)
plt.imshow(resized)
plt.title("True")

# plt.subplot(132)
# plt.imshow(origi_img)
# plt.title("original")

plt.subplot(122)
plt.imshow(im_copy_resized)
plt.title("Predicted")
# Out:
# Text(0.5, 1.0, 'Predicted')

# %%
max_6 = test_images_stacked[6]
min_5 = test_images_stacked[5]
mid_18 = test_images_stacked[18]

max_true_mask = test_masks_stacked[6]
min_true_mask = test_masks_stacked[5]
mid_true_mask = test_masks_stacked[18]


max_pred_mask = pred_masks[6]
min_pred_mask = pred_masks[5]
mid_pred_mask = pred_masks[18]

# %%
def convertRGB(image):
    im_gray_convert = image[:,:,0].astype(np.float32) # cv2 accepts dimension(256,256) and float32
    # convert to RGB
    im_rgb = cv2.cvtColor(im_gray_convert, cv2.COLOR_GRAY2RGB)
    return im_rgb

# %%
def drawTwoMasks(image, idx):
    image[:,:,0] = image[:,:,0] + test_masks[idx]
    image[:,:,1] = image[:,:,1] + pred_masks[idx][:,:,0]
    return image

# %%
max_6 = convertRGB(max_6)
max_6.shape
# Out:
# (256, 256, 3)

# %%
max_6 = drawTwoMasks(max_6,6)
plt.imshow(max_6)

# %%
min_5 = convertRGB(min_5)
min_5 = drawTwoMasks(min_5,5)

mid_18 = convertRGB(mid_18)
mid_18 = drawTwoMasks(mid_18,18)

# %%
np.unique(test_masks[1] == test_masks_stacked[1])
# Out:
# array([ True])

# %%
plt.rcParams["figure.figsize"] = (10,10)
plt.subplot(131)
plt.imshow(max_6, cmap='gray')
plt.title("Max Error")

plt.subplot(132)
plt.imshow(mid_18, cmap='gray')
plt.title("Mid Error")

plt.subplot(133)
plt.imshow(min_5, cmap='gray')
plt.title("Min Error")
# Out:
# Text(0.5, 1.0, 'Min Error')

# %%
plt.rcParams["figure.figsize"] = (10,10)
max_6 = convertRGB(test_images_stacked[6])
min_5 = convertRGB(test_images_stacked[5])
mid_18 = convertRGB(test_images_stacked[18])

max_6_copy = max_6.copy()
min_5_copy = min_5.copy()
mid_18_copy = mid_18.copy()

max_true_mask = test_masks_stacked[6]
min_true_mask = test_masks_stacked[5]
mid_true_mask = test_masks_stacked[18]

max_pred_mask = pred_masks[6]
min_pred_mask = pred_masks[5]
mid_pred_mask = pred_masks[18]

max_6[:,:,1] = max_6[:,:,1] + max_true_mask
min_5[:,:,1] = min_5[:,:,1] + min_true_mask
mid_18[:,:,1] = mid_18[:,:,1] + mid_true_mask

max_6_copy[:,:,0] = max_6_copy[:,:,0] + max_pred_mask[:,:,0]
min_5_copy[:,:,0] = min_5_copy[:,:,0] + min_pred_mask[:,:,0]
mid_18_copy[:,:,0] = mid_18_copy[:,:,0] + mid_pred_mask[:,:,0]

# %%
plt.subplot(231)
plt.imshow(max_6)
plt.title("Max Error: True")

plt.subplot(232)
plt.imshow(mid_18)
plt.title("Mid Error: True")

plt.subplot(233)
plt.imshow(min_5)
plt.title("Min Error: True")

plt.subplot(234)
plt.imshow(max_6_copy)
plt.title("Max Error: Pred")

plt.subplot(235)
plt.imshow(mid_18_copy)
plt.title("Mid Error: Pred")

plt.subplot(236)
plt.imshow(min_5_copy, cmap='gray')
plt.title("Min Error: Pred")
# Out:
# Text(0.5, 1.0, 'Min Error: Pred')

# %%
unet.evaluate(test_images_stacked, test_masks_stacked)
# Out:
# 2/2 [==============================] - 1s 189ms/step - loss: 0.4874 - dice_coeff: 0.5107
# [0.4874004125595093, 0.5107247829437256]

# %%
plt.subplot(321)
plt.imshow(max_6)
plt.title("Max Error: True")

plt.subplot(322)
plt.imshow(max_6_copy)
plt.title("Max Error: Pred")

plt.subplot(323)
plt.imshow(mid_18)
plt.title("Mid Error: True")

plt.subplot(324)
plt.imshow(mid_18_copy)
plt.title("Mid Error: Pred")

plt.subplot(325)
plt.imshow(min_5)
plt.title("Min Error: True")

plt.subplot(326)
plt.imshow(min_5_copy)
plt.title("Min Error: Pred")
# Out:
# Text(0.5, 1.0, 'Min Error: Pred')
